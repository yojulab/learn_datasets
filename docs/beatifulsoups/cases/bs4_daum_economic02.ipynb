# %%
import requests

# %% [markdown]
# http://media.daum.net/economic/

# %%
# path = 'https://www.genie.co.kr/chart/top200'
path = 'https://news.daum.net/economic'
req = requests.get(path)

# %%
req.status_code
# Out:
# 200

# %%
req.content
# Out:
# b'\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum \xeb\x89\xb4\xec\x8a\xa4" />\n<meta property="og:site_name" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4" />\n<meta property="og:title" content="\xea\xb2\xbd\xec\xa0\x9c"/>\n<meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4" />\n<meta property="og:url" content="https://news.daum.net/economic" />\n<link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<title>\xea\xb2\xbd\xec\xa0\x9c | \xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4</title>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/e3d4c16/common.c
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(req.content, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
result = soup.select('div > ul.list_timenews > li > strong')
type(result), len(result)
# Out:
# (bs4.element.ResultSet, 0)

# %%
result[0]
# Out:
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20210624165925905" data-tiara-id="20210624165925905" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20210624165925905">신세계, 3.4조에 이베이코리아 인수..e커머스 2위로 도약</a>

# %%
tag = result[0]

# %%
tag.text
# Out:
# '재산권 침해 논란에 국토부·서울시 "조합원 지위 제한, 소급·일괄적용 아냐"'

# %%
tag['href']
# Out:
# 'https://news.v.daum.net/v/20210624161729105'

# %%
for tag in result:
    print(tag.text.strip(), tag['href'].strip())
# Out:
# 재산권 침해 논란에 국토부·서울시 "조합원 지위 제한, 소급·일괄적용 아냐" https://news.v.daum.net/v/20210624161729105
# 삼성·현대차 등 금융복합기업 감독 본격화..3년마다 위험평가 https://news.v.daum.net/v/20210624161440968
# '급식 몰아주기'에 사상 최대 과징금..삼성 "행정소송할 것" https://news.v.daum.net/v/20210624160716684
# 금투협 채권포럼.."통화정책 정상화 임박, 만기별 금리 차별화" https://news.v.daum.net/v/20210624160022231
# 재난지원금 소득하위 80%, 자영업자 지원 600만원 이상 유력 https://news.v.daum.net/v/20210624160147331
